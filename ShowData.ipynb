# %%
import csv
import pandas as pd
import pyarrow as pa
import pyarrow.parquet as pq

# %%
df_weather = pd.read_csv("datasets/weather.csv")
print(df_weather)
# Out:
#       year  month  day  hour  temp temp_source  rhum rhum_source  prcp  \
# 0     2024      1    1     0   6.1    isd_lite    47    isd_lite   0.0
# 1     2024      1    1     1   6.1    isd_lite    45    isd_lite   0.0
# 2     2024      1    1     2   6.1    isd_lite    47    isd_lite   0.0
# 3     2024      1    1     3   6.1    isd_lite    51    isd_lite   0.0
# 4     2024      1    1     4   6.1    isd_lite    51    isd_lite   0.0
# ...    ...    ...  ...   ...   ...         ...   ...         ...   ...
# 8779  2024     12   31    19  11.1    isd_lite    44    isd_lite   0.0
# 8780  2024     12   31    20  11.1    isd_lite    50    isd_lite   0.0
# 8781  2024     12   31    21  10.0    isd_lite    58    isd_lite   0.0
# 8782  2024     12   31    22  10.0    isd_lite    61    isd_lite   0.0
# 8783  2024     12   31    23   9.4    isd_lite    66    isd_lite   0.0
#
#      prcp_source  ...  wspd  wspd_source  wpgt wpgt_source    pres  \
# ...

# %%
print(df_weather.columns)
# Out:
# Index(['year', 'month', 'day', 'hour', 'temp', 'temp_source', 'rhum',
#        'rhum_source', 'prcp', 'prcp_source', 'snwd', 'snwd_source', 'wdir',
#        'wdir_source', 'wspd', 'wspd_source', 'wpgt', 'wpgt_source', 'pres',
#        'pres_source', 'cldc', 'cldc_source', 'coco', 'coco_source'],
#       dtype='str')

# %%
df_taxi = pd.read_csv("datasets/taxi_zone_lookup.csv")
print(df_taxi)
# Out:
#      LocationID        Borough                     Zone service_zone
# 0             1            EWR           Newark Airport          EWR
# 1             2         Queens              Jamaica Bay    Boro Zone
# 2             3          Bronx  Allerton/Pelham Gardens    Boro Zone
# 3             4      Manhattan            Alphabet City  Yellow Zone
# 4             5  Staten Island            Arden Heights    Boro Zone
# ..          ...            ...                      ...          ...
# 260         261      Manhattan       World Trade Center  Yellow Zone
# 261         262      Manhattan           Yorkville East  Yellow Zone
# 262         263      Manhattan           Yorkville West  Yellow Zone
# 263         264        Unknown                      NaN          NaN
# 264         265            NaN           Outside of NYC          NaN
#
# [265 rows x 4 columns]

# %%
yellow_tripdata = pq.read_table("datasets/yellow_tripdata_2024-01.parquet")
df_yellow_tripdata = yellow_tripdata.to_pandas()
print(df_yellow_tripdata)
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0               2  2024-01-01 00:57:55   2024-01-01 01:17:43              1.0
# 1               1  2024-01-01 00:03:00   2024-01-01 00:09:36              1.0
# 2               1  2024-01-01 00:17:06   2024-01-01 00:35:01              1.0
# 3               1  2024-01-01 00:36:38   2024-01-01 00:44:56              1.0
# 4               1  2024-01-01 00:46:51   2024-01-01 00:52:57              1.0
# ...           ...                  ...                   ...              ...
# 2964619         2  2024-01-31 23:45:59   2024-01-31 23:54:36              NaN
# 2964620         1  2024-01-31 23:13:07   2024-01-31 23:27:52              NaN
# 2964621         2  2024-01-31 23:19:00   2024-01-31 23:38:00              NaN
# 2964622         2  2024-01-31 23:07:23   2024-01-31 23:25:14              NaN
# 2964623         1  2024-01-31 23:58:25   2024-02-01 00:13:30              NaN
#
# ...

# %%
yellow_tripdata = pq.read_table("datasets/yellow_tripdata_2024-02.parquet")
df_yellow_tripdata = yellow_tripdata.to_pandas()
print(df_yellow_tripdata)
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0               2  2024-02-01 00:04:45   2024-02-01 00:19:58              1.0
# 1               2  2024-02-01 00:56:31   2024-02-01 01:10:53              1.0
# 2               2  2024-02-01 00:07:50   2024-02-01 00:43:12              2.0
# 3               1  2024-02-01 00:01:49   2024-02-01 00:10:47              1.0
# 4               1  2024-02-01 00:37:35   2024-02-01 00:51:15              1.0
# ...           ...                  ...                   ...              ...
# 3007521         2  2024-02-29 23:20:17   2024-02-29 23:28:25              NaN
# 3007522         2  2024-02-29 23:38:37   2024-02-29 23:49:37              NaN
# 3007523         2  2024-02-29 23:14:40   2024-02-29 23:19:29              NaN
# 3007524         1  2024-02-29 23:12:06   2024-02-29 23:21:53              NaN
# 3007525         2  2024-02-29 23:16:42   2024-02-29 23:37:45              NaN
#
# ...

# %%
print(df_air.columns) # format 6.2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 print(df_air.columns) # format 6.2
#
# NameError: name 'df_air' is not defined

# %%
df_air = pd.read_csv("datasets/air_quality/hourly_88101_2024.csv")
print(df_air)
# Out:
# C:\Users\Mohammad Asfour\AppData\Local\Temp\ipykernel_6664\1410380945.py:1: DtypeWarning: Columns (0: Qualifier) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_air = pd.read_csv("datasets/air_quality/hourly_88101_2024.csv")
#          State Code  County Code  Site Num  Parameter Code  POC   Latitude  \
# 0                 1            3        10           88101    3  30.497478
# 1                 1            3        10           88101    3  30.497478
# 2                 1            3        10           88101    3  30.497478
# 3                 1            3        10           88101    3  30.497478
# 4                 1            3        10           88101    3  30.497478
# ...             ...          ...       ...             ...  ...        ...
# 8139546          80           26         6           88101    1  31.291293
# 8139547          80           26         6           88101    1  31.291293
# ...

# %%
# !pip install re
# Out:
# ERROR: Could not find a version that satisfies the requirement re (from versions: none)
#
# [notice] A new release of pip is available: 26.0.1 -> 26.2.1
# [notice] To update, run: C:\Users\Mohammad Asfour\AppData\Local\Python\pythoncore-3.14-64\python.exe -m pip install --upgrade pip
# ERROR: No matching distribution found for re
